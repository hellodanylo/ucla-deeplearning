# %%
from scipy.stats import truncnorm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
sns.set_context('talk')

# %%
a, b = 0, 0.3

pd.DataFrame(
    [truncnorm.stats(a, b, moments='mvsk')], 
    index=['trunc_norm'],
    columns=['mean', 'varince', 'skew', 'kurtosis']
).round(2)
# Out:
#                            mean               varince                  skew  \
# trunc_norm  0.14887840902111762  0.007476771315361789  0.015524889675326817
#
#                        kurtosis
# trunc_norm  -1.1965787676052877

# %%
x = np.linspace(truncnorm.ppf(0.00001, a, b), truncnorm.ppf(0.9999, a, b), 100)
pdf = truncnorm.pdf(x, a, b)

plt.title(f'Truncated Normal ({a}, {b})')
plt.plot(x, pdf, lw=3, alpha=0.6, label='truncnorm pdf')
plt.axvline(mean, 0, 1, color='orange', label='truncnorm mean')
plt.legend()
