# %%
from stable_diffusion_tf.stable_diffusion import Text2Image
from PIL import Image
import matplotlib.pyplot as plt

# %%
generator = Text2Image(
    img_height=512,
    img_width=512,
    jit_compile=False,
)

# %%
p = 'pine forest, brown bear, illustration, oil painting'

# %%
img = generator.generate(
    p,
    num_steps=30,
    unconditional_guidance_scale=6,
    temperature=0.6,
    batch_size=1,
    seed=42
)
plt.imshow(img[0])
# Out:
#  30 991:   0% 0/31 [00:00<?, ?it/s]2022-09-24 19:02:07.498461: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8401
# 2022-09-24 19:02:07.751591: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-24 19:02:07.752568: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-24 19:02:07.752581: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-09-24 19:02:07.753133: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-24 19:02:07.753168: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#   0   1: 100% 31/31 [00:24<00:00,  1.24it/s]

# %%
#Image.fromarray(img[0]).save("stable_diffusion.png")
