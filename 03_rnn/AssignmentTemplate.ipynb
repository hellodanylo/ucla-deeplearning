# %%
# If you are using SageMaker Notebook Instance:
# You need to do the following in order to run GPU-enabled Keras training.
# 1. Make sure you are in us-west-2 (Oregon) region.
# 2. Request service limit increase for ml.p2.xlarge instance type to 1.
# 3. Change the notebook instance type to a ml.p2.xlarge

# If you are using Google Colab:
# You need to do the following in order to run GPU-enabled Keras training.
# 1. Runtime -> Change runtime type -> Hardware accelerator -> GPU
# 2. Restart the kernel.
# 3. It's your responsibility to install all required Python packages in Colab.

# %%
# Run this cell to configure Tensorflow to use your GPU
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if not gpus:
    print(f'No GPU found, but higly recommended for this assignment')
    
for gpu in gpus:
    print(gpu)
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
sns.set_context('talk')

# %%
# %%capture
prefix = 'https://danylo-ucla.s3-us-west-2.amazonaws.com/app/storage/weather/jobs/transform_batch/20200927-010303_94e076593fe6eeb97c0a5f442b4198dc'

train_X = pd.read_parquet(f'{prefix}/train_x.parquet')
train_y = pd.read_parquet(f'{prefix}/train_y.parquet')

validate_X = pd.read_parquet(f'{prefix}/validate_x.parquet')
validate_y = pd.read_parquet(f'{prefix}/validate_y.parquet')

test_X = pd.read_parquet(f'{prefix}/test_x.parquet')
test_y = pd.read_parquet(f'{prefix}/test_y.parquet')

score_X = pd.read_parquet(f'{prefix}/score_x.parquet')

condition_window = 24
prediction_window = 24
features_length = 4

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 826464 entries, ('Albuquerque/1108/0', Timestamp('2015-02-16 09:00:00')) to ('Vancouver/806/12', Timestamp('2014-07-03 04:00:00'))
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temperature  826464 non-null  float64
#  1   humidity     826464 non-null  float64
#  2   pressure     826464 non-null  float64
#  3   wind_speed   826464 non-null  float64
# dtypes: float64(4)
# memory usage: 32.3+ MB

# %%
score_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 57576 entries, ('Albuquerque/2249/0', Timestamp('2017-07-15 13:00:00')) to ('Vancouver/2623/10', Timestamp('2017-07-07 20:00:00'))
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  57576 non-null  float64
#  1   humidity     57576 non-null  float64
#  2   pressure     57576 non-null  float64
#  3   wind_speed   57576 non-null  float64
# dtypes: float64(4)
# memory usage: 2.2+ MB

# %%
train_X.head()
# Out:
#                                         temperature  humidity  pressure  \
# sample             time
# Albuquerque/1108/0 2015-02-16 09:00:00   276.323000      47.0    1031.0
#                    2015-02-16 10:00:00   275.097667      45.0    1032.0
#                    2015-02-16 11:00:00   273.931333      48.0    1032.0
#                    2015-02-16 12:00:00   274.380000      46.0    1033.0
#                    2015-02-16 13:00:00   272.675333      51.0    1033.0
#
#                                         wind_speed
# sample             time
# Albuquerque/1108/0 2015-02-16 09:00:00         3.0
#                    2015-02-16 10:00:00         3.0
#                    2015-02-16 11:00:00         2.0
#                    2015-02-16 12:00:00         2.0
#                    2015-02-16 13:00:00         1.0

# %%
train_X.groupby('sample').size().head()
# Out:
# sample
# Albuquerque/1108/0    24
# Albuquerque/1108/1    24
# Albuquerque/1108/2    24
# Albuquerque/1112/0    24
# Albuquerque/1112/1    24
# dtype: int64

# %%
train_X.loc['Albuquerque/1112/1'].head()
# Out:
#                      temperature  humidity  pressure  wind_speed
# time
# 2015-02-20 18:00:00   282.116500      46.0    1023.0         3.0
# 2015-02-20 19:00:00   287.061667      40.0    1021.0         4.0
# 2015-02-20 20:00:00   288.236333      38.0    1019.0         4.0
# 2015-02-20 21:00:00   286.928000      35.0    1020.0         4.0
# 2015-02-20 22:00:00   288.930333      34.0    1017.0         5.0

# %%
train_X.loc['Albuquerque/1112/1'].plot(subplots=True, layout=(2, 2), figsize=[15, 10])
plt.tight_layout()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_X)

scaled_X = {
    'train': scaler.transform(train_X),
    'validate': scaler.transform(validate_X),
    'test': scaler.transform(test_X),
    'score': scaler.transform(score_X),
}

# %%
# Keras RNN cells expect inputs with 3 dimensions:
# (batch_size, condition_window, features_length)
# Each RNN cell takes a vector of features_length
# at each time step of condition_window.
# Internal RNN cell state is reset between different batch samples.

# Let's review current shapes of the input, and the desired shapes.

def expected_X_shape(actual_X_shape):
    return (int(actual_X_shape[0]/condition_window), condition_window, features_length)

def expected_y_shape(actual_y_shape):
    return (int(actual_y_shape[0]/prediction_window), prediction_window)


pd.DataFrame({
    'actual shape': [
        train_X.shape, 
        train_y.shape,
    ],
    'expected shape': [
        expected_X_shape(train_X.shape), 
        expected_y_shape(train_y.shape), 
    ],
}, index=['train_X', 'train_y'])
# Out:
#         actual shape  expected shape
# train_X  (826464, 4)  (34436, 24, 4)
# train_y  (826464, 4)     (34436, 24)

# %%
# Exepected shape can be achieved with a simple reshape call.
# Note that these are not Pandas data frames any more,
# but Numpy n-dimensional arrays.
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.reshape.html

def frame_to_ndarray(frame_X, frame_y):
    X_nd = frame_X.reshape(-1, condition_window, features_length).astype('float32')
    y_nd = frame_y['temperature'].values.reshape(-1, prediction_window).astype('float32')
    return X_nd, y_nd

train_X_nd, train_y_nd = frame_to_ndarray(scaled_X['train'], train_y)
validate_X_nd, validate_y_nd = frame_to_ndarray(scaled_X['validate'], validate_y)

# Task: Transform other segments of the dataset (test, and score).
# Enter your code here.

# %%
# Let's confirm the expected shape.

pd.DataFrame({
    'actual shape': [
        train_X_nd.shape, 
        train_y_nd.shape,
        validate_X_nd.shape,
        validate_y_nd.shape,
    ],
    'expected shape': [
        expected_X_shape(train_X.shape), 
        expected_y_shape(train_y.shape), 
        expected_X_shape(validate_X.shape), 
        expected_y_shape(validate_y.shape), 
    ]},
    index=['train_X', 'train_y', 'validate_X', 'validate_y']
)
# Out:
#               actual shape  expected shape
# train_X     (34436, 24, 4)  (34436, 24, 4)
# train_y        (34436, 24)     (34436, 24)
# validate_X   (2288, 24, 4)   (2288, 24, 4)
# validate_y      (2288, 24)      (2288, 24)

# %%
from tensorflow.python.keras.layers import Dense, CuDNNGRU, BatchNormalization
from tensorflow.python.keras.models import Sequential
from tensorflow.python import GlorotUniform

# If you would like to train on CPU, use this implementation of GRU:
# from tensorflow.python.keras.layers.recurrent import GRU

layers = [
        CuDNNGRU(
            input_shape=(condition_window, features_length),
            units=100,
            return_sequences=True,
            kernel_initializer=GlorotUniform(seed=42)
        ),
        BatchNormalization(),
        CuDNNGRU(
            units=50,
            return_sequences=True,
            kernel_initializer=GlorotUniform(seed=43)
        ),
        BatchNormalization(),
        CuDNNGRU(
            units=25,
            return_sequences=False,
            kernel_initializer=GlorotUniform(seed=44)
        ),
        BatchNormalization(),
        Dense(
            kernel_initializer=GlorotUniform(seed=45),
            units=prediction_window,
            activation='linear'
        )
]

model = Sequential(layers)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnngru (CuDNNGRU)         (None, 24, 100)           31800
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 100)           400
# _________________________________________________________________
# cu_dnngru_1 (CuDNNGRU)       (None, 24, 50)            22800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 50)            200
# _________________________________________________________________
# cu_dnngru_2 (CuDNNGRU)       (None, 25)                5775
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25)                100
# _________________________________________________________________
# dense (Dense)                (None, 24)                624
# =================================================================
# Total params: 61,699
# Trainable params: 61,349
# Non-trainable params: 350
# _________________________________________________________________

# %%
from utils import r2_score, mean_error
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(lr=0.01),
    loss='mean_squared_error',
    metrics=[
        'mean_absolute_error',
        r2_score,
        mean_error
    ]
)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, ReduceLROnPlateau, EarlyStopping

history = model.fit(
    train_X_nd,
    train_y_nd,
    validation_data=(validate_X_nd, validate_y_nd),
    epochs=20,
    batch_size=100,
    callbacks=[
        TerminateOnNaN(),
        ReduceLROnPlateau(
            monitor='loss',
            min_delta=0.1,
            patience=5,
            cooldown=10,
            verbose=1
        ),
        EarlyStopping(
            monitor='loss',
            min_delta=0.1,
            patience=10
        )
    ]
)
# Out:
# Epoch 1/20
# 345/345 [==============================] - 9s 26ms/step - loss: 32100.0664 - mean_absolute_error: 144.8370 - r2_score: -238.1285 - mean_error: -144.4751 - val_loss: 36.1516 - val_mean_absolute_error: 4.8348 - val_r2_score: 0.0896 - val_mean_error: 2.8281 - lr: 0.0100
# Epoch 2/20
# 345/345 [==============================] - 9s 25ms/step - loss: 22.4582 - mean_absolute_error: 3.7326 - r2_score: 0.8329 - mean_error: -0.1735 - val_loss: 25.7461 - val_mean_absolute_error: 3.9157 - val_r2_score: 0.3028 - val_mean_error: -0.8334 - lr: 0.0100
# Epoch 3/20
# 345/345 [==============================] - 9s 25ms/step - loss: 21.0927 - mean_absolute_error: 3.6065 - r2_score: 0.8427 - mean_error: -0.0080 - val_loss: 25.5514 - val_mean_absolute_error: 3.8564 - val_r2_score: 0.3205 - val_mean_error: -1.3558 - lr: 0.0100
# Epoch 4/20
# 345/345 [==============================] - 9s 25ms/step - loss: 18.5441 - mean_absolute_error: 3.3645 - r2_score: 0.8622 - mean_error: -0.0046 - val_loss: 22.9550 - val_mean_absolute_error: 3.7455 - val_r2_score: 0.3578 - val_mean_error: -1.0985 - lr: 0.0100
# Epoch 5/20
# 345/345 [==============================] - 9s 25ms/step - loss: 16.6697 - mean_absolute_error: 3.1681 - r2_score: 0.8755 - mean_error: -0.0013 - val_loss: 20.4372 - val_mean_absolute_error: 3.4871 - val_r2_score: 0.4669 - val_mean_error: 0.3582 - lr: 0.0100
# Epoch 6/20
# 345/345 [==============================] - 9s 25ms/step - loss: 14.3156 - mean_absolute_error: 2.9183 - r2_score: 0.8935 - mean_error: 0.0066 - val_loss: 21.0012 - val_mean_absolute_error: 3.4330 - val_r2_score: 0.4327 - val_mean_error: 0.1791 - lr: 0.0100
# Epoch 7/20
# 345/345 [==============================] - 9s 25ms/step - loss: 13.1758 - mean_absolute_error: 2.7885 - r2_score: 0.9021 - mean_error: -0.0167 - val_loss: 25.8653 - val_mean_absolute_error: 4.0305 - val_r2_score: 0.3190 - val_mean_error: 2.0105 - lr: 0.0100
# Epoch 8/20
# 345/345 [==============================] - 9s 25ms/step - loss: 12.4926 - mean_absolute_error: 2.7098 - r2_score: 0.9072 - mean_error: 0.0051 - val_loss: 21.5154 - val_mean_absolute_error: 3.4846 - val_r2_score: 0.4205 - val_mean_error: -0.1295 - lr: 0.0100
# Epoch 9/20
# 345/345 [==============================] - 9s 25ms/step - loss: 11.5468 - mean_absolute_error: 2.6095 - r2_score: 0.9138 - mean_error: -0.0028 - val_loss: 19.8333 - val_mean_absolute_error: 3.4040 - val_r2_score: 0.4824 - val_mean_error: 0.3404 - lr: 0.0100
# Epoch 10/20
# 345/345 [==============================] - 9s 25ms/step - loss: 11.9110 - mean_absolute_error: 2.6447 - r2_score: 0.9112 - mean_error: 0.0022 - val_loss: 19.5496 - val_mean_absolute_error: 3.3627 - val_r2_score: 0.4733 - val_mean_error: 0.5637 - lr: 0.0100
# Epoch 11/20
# 345/345 [==============================] - 9s 25ms/step - loss: 11.2482 - mean_absolute_error: 2.5732 - r2_score: 0.9163 - mean_error: -0.0145 - val_loss: 20.8497 - val_mean_absolute_error: 3.4806 - val_r2_score: 0.4386 - val_mean_error: 0.8934 - lr: 0.0100
# Epoch 12/20
# 345/345 [==============================] - 9s 25ms/step - loss: 11.1584 - mean_absolute_error: 2.5665 - r2_score: 0.9168 - mean_error: 0.0025 - val_loss: 19.6339 - val_mean_absolute_error: 3.3768 - val_r2_score: 0.4866 - val_mean_error: 0.4682 - lr: 0.0100
# Epoch 13/20
# 345/345 [==============================] - 9s 25ms/step - loss: 11.1844 - mean_absolute_error: 2.5645 - r2_score: 0.9163 - mean_error: 0.0065 - val_loss: 19.8887 - val_mean_absolute_error: 3.3788 - val_r2_score: 0.4744 - val_mean_error: -0.2303 - lr: 0.0100
# Epoch 14/20
# 345/345 [==============================] - 9s 25ms/step - loss: 10.6363 - mean_absolute_error: 2.5004 - r2_score: 0.9209 - mean_error: -0.0084 - val_loss: 21.3793 - val_mean_absolute_error: 3.5222 - val_r2_score: 0.4455 - val_mean_error: 0.9063 - lr: 0.0100
# Epoch 15/20
# 345/345 [==============================] - 8s 25ms/step - loss: 10.2629 - mean_absolute_error: 2.4646 - r2_score: 0.9237 - mean_error: 0.0106 - val_loss: 21.2138 - val_mean_absolute_error: 3.5211 - val_r2_score: 0.4032 - val_mean_error: -0.5808 - lr: 0.0100
# Epoch 16/20
# 345/345 [==============================] - 9s 25ms/step - loss: 10.9352 - mean_absolute_error: 2.5452 - r2_score: 0.9183 - mean_error: -0.0243 - val_loss: 29.0909 - val_mean_absolute_error: 4.2973 - val_r2_score: 0.1699 - val_mean_error: 3.0206 - lr: 0.0100
# Epoch 17/20
# 345/345 [==============================] - 9s 25ms/step - loss: 10.9169 - mean_absolute_error: 2.5419 - r2_score: 0.9188 - mean_error: 0.0233 - val_loss: 21.2006 - val_mean_absolute_error: 3.4738 - val_r2_score: 0.3756 - val_mean_error: -0.9067 - lr: 0.0100
# Epoch 18/20
# 345/345 [==============================] - 9s 25ms/step - loss: 10.6508 - mean_absolute_error: 2.5133 - r2_score: 0.9207 - mean_error: -0.0014 - val_loss: 22.9894 - val_mean_absolute_error: 3.6785 - val_r2_score: 0.3800 - val_mean_error: 1.7716 - lr: 0.0100
# Epoch 19/20
# 345/345 [==============================] - 9s 25ms/step - loss: 10.2852 - mean_absolute_error: 2.4722 - r2_score: 0.9234 - mean_error: -6.0151e-04 - val_loss: 21.4107 - val_mean_absolute_error: 3.4578 - val_r2_score: 0.4238 - val_mean_error: -0.0449 - lr: 0.0100
# Epoch 20/20
# 345/345 [==============================] - 9s 25ms/step - loss: 9.9843 - mean_absolute_error: 2.4320 - r2_score: 0.9257 - mean_error: -0.0123 - val_loss: 23.2993 - val_mean_absolute_error: 3.8061 - val_r2_score: 0.3604 - val_mean_error: 1.8208 - lr: 0.0100

# %%
# Note that Keras evaluates metrics in batches,
# which is okay for averaging-stable metrics like ME, MSE, and MAE,
# but R2 requires full dataset to evaluate precisely.

# This implies two things:
# 1) R2 as reported during training is not precise
# 2) when evaluating R2 after training, batch size must match dataset size

nd_array_by_segment = {
    'train': (train_X_nd, train_y_nd),
    'validate': (validate_X_nd, validate_y_nd)
}

metrics_by_segment = {
    segment: model.evaluate(
        X_nd, 
        y_nd, 
        verbose=0, 
        batch_size=X_nd.shape[0]
    )
    for segment, (X_nd, y_nd) in nd_array_by_segment.items()
}

rnn_metrics = pd.concat([
    pd.DataFrame(
        data=[metrics], 
        columns=['MSE', 'MAE', 'R2', 'ME'], 
        index=[segment]
    )
    for segment, metrics in metrics_by_segment.items()
])

rnn_metrics = pd.DataFrame([rnn_metrics.unstack()], index=['rnn'])\
    .swaplevel(axis=1, i=0, j=1)\
    .reindex(nd_array_by_segment.keys(), axis=1, level=0)\
    .round(2)

rnn_metrics
# Out:
#      train                   validate
#        MSE   MAE    R2    ME      MSE   MAE    R2    ME
# rnn  11.15  2.61  0.92  1.71     23.3  3.81  0.74  1.81

# %%
from utils import SegmentDataset, baseline_metrics

segment_names = ['train', 'validate']
panel_dataset = SegmentDataset.from_pq_workdir(prefix, segment_names, ['x', 'y'])
baseline_metrics = baseline_metrics(panel_dataset)

# %%
pd.concat([
    baseline_metrics,
    rnn_metrics
], axis=0).loc[:, (slice(None), ['MSE', 'R2'])].round(2)
# Out:
#             train       validate
#               MSE    R2      MSE    R2
# mean        26.77  0.80    37.23  0.58
# constant    21.82  0.84    40.25  0.54
# regression  30.53  0.78    29.94  0.66
# rnn         11.15  0.92    23.30  0.74

# %%
from utils import nd_target_like_panel, plot_random_forecasts

train_y_hat = nd_target_like_panel(train_y, model.predict(train_X_nd))

plot_random_forecasts(
    train_X['temperature'],
    train_y['temperature'],
    train_y_hat.rename(columns={'temperature': 'forecast'})
)

# %%
# TODO: save your predictions on the Score segment as a Pandas data frame
# into a variable named score_y_hat.

# Keras model will output an array of shape (2399, 24) for the Score segment,
# however the expected shape of the submitted data frame is (57576, 1).
# 57576 = 2399 (count of samples in Score segment) x 24 (prediction window).
# Use NumPy's reshape() or ravel() functions to achieve this.

# Finally, the data frame needs to have string column names in order to be saved
# as a Parquet file. If you convert a NumPy array to Pandas data frame,
# column names will be integers, but you can replace the columns names.
# There was a similar example of this in the notebook from the first assignment.

# Expected output: (Index(['temperature'], dtype='object'), (57576, 1))
score_y_hat.columns, score_y_hat.shape

# %%
# Once you are satisfied with your model,
# your need to submit 4 files:
# 1. this notebook and/or any other Python scripts
# 2. Model definition in JSON format
# 3. Model parameters in H5 format
# 4. temperature forecast for the Score segment

import os
model_dir = 'weathernet_model'
os.makedirs(model_dir, exist_ok=True)

# Save model definition:
import json
with open(f'{model_dir}/keras_model.json', 'w') as f:
    model_json = json.dumps(json.loads(model.to_json()), indent=True)
    f.write(model_json)

# Save the learned parameters.
model.save_weights(f"{model_dir}/keras_parameters.h5")

# Finally, let's save the forecast.
score_y_hat.to_parquet(f'{model_dir}/score_y_hat.parquet')
